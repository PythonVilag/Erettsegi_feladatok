# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Python_alapjai/blob/main/00_Bevezetes_es_kurzus_informaciok/00_Bevezetes_es_kurzus_informaciok.ipynb)

# %% [markdown]
# ## Feladat: [2021_II Sudoku](#) <br> <br>
#
#
# Készítette: Mizsák Dániel, Pecsenye Samu
#
# Minden jellegű visszajelzést örömmel fogadok az [alábbi e-mail címen.](mailto:info@pythonvilag.hu)

# %% [markdown]
# # Szükséges adatfájlok letöltése a futtató környezetbe

# %%
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2021/2021_II/Forrasok/konnyu.txt
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2021/2021_II/Forrasok/kozepes.txt
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2021/2021_II/Forrasok/nehez.txt

# %% [markdown]
# # 1. Feladat

# %%
print('1. feladat')

bemeneti_filenev = input('Adja meg a bemeneti fájl nevét! ')
bemeneti_sor = int(input('Adja meg egy sor számát! ')) - 1
bemeneti_oszlop = int(input('Adja meg egy oszlop számát! ')) - 1
# Out:
# 1. feladat
# Adja meg a bemeneti fájl nevét! konnyu.txt
# Adja meg egy sor számát! 1
# Adja meg egy oszlop számát! 1

# %% [markdown]
# # 2. Feladat

# %%
tablazat = list()
lepesek = list()
x = int()

with open(file=bemeneti_filenev, mode='r') as forras_file:
    for sorszam, sor in enumerate(forras_file):
        sor_list = sor.strip().split()
        sor_list = [int(elem) for elem in sor_list]
        if sorszam < 9:
            tablazat.append(sor_list)
        else:
            lepesek.append(sor_list)

# %% [markdown]
# Alternatív megoldás (🐟):
#
# ```python
# ...
#     for sorszam, sor in enumerate(forras_file):
#         sor_list = sor.strip().split()
#         sor_list = list(map(int, sor_list))
# ...
#
# ```

# %% [markdown]
# # 3. Feladat

# %%
print('\n3. feladat')

cella = tablazat[bemeneti_sor][bemeneti_oszlop]
def resztablazat(sor, oszlop):
    """
    A resztablazat szama jobbra 1-gyel növekszik 3 cellánként,
    lefelé peding 3-mal. A bal felső pedig az 1-es szamú.
    """
    resztabla_sorszam = (sor//3)*3 + (oszlop//3) + 1
    return resztabla_sorszam

if cella == 0:
    print('Az adott helyet még nem töltötték ki.')
else:
    print(f'Az adott helyen szereplő szám: {cella}')

resztabla_sorszam = resztablazat(bemeneti_sor, bemeneti_oszlop)
print(f'A hely a(z) {resztabla_sorszam} résztáblázathoz tartozik.')
# Out:
# 3. feladat
# Az adott helyen szereplő szám: 5
# A hely a(z) 1 résztáblázathoz tartozik.

# %% [markdown]
# # 4. Feladat

# %%
print('\n4. feladat')

nullak_szama = 0
for sor_list in tablazat:
    nullak_szama += sor_list.count(0)
print(f'Az üres helyek aránya: {round(100*nullak_szama/81, 1)}%')
# Out:
# 4. feladat
# Az üres helyek aránya: 17.3%

# %% [markdown]
# # 5. Feladat

# %%
print('\n5. feladat')

for lepes in lepesek:
    szam = lepes[0]
    sor = lepes[1] - 1
    oszlop = lepes[2] - 1

    print(f'A kiválasztott sor: {sor+1} oszlop: {oszlop+1} a szám: {szam}')
    if tablazat[sor][oszlop] != 0:
        print('A helyet már kitöltötték.')
    elif szam in tablazat[sor]: 
        print('Az adott sorban már szerepel a szám.')
    elif szam in [sor_list[oszlop] for sor_list in tablazat]:
        print('Az adott oszlopban már szerepel a szám.')
    else:
        resztabla_flag = False
        balfelso_sor = (sor//3)*3
        balfelso_oszlop = (oszlop//3)*3
        for sorszam in range(balfelso_sor, balfelso_sor+3):
            for oszlopszam in range(balfelso_oszlop, balfelso_oszlop+3):
                if szam == tablazat[sorszam][oszlopszam]:
                    resztabla_flag = True
        if resztabla_flag:
            print('Az adott résztáblázatban már szerepel a szám.')
        else:
            print('A lépés megtehető.')
    print()
# Out:
# 5. feladat
# A kiválasztott sor: 2 oszlop: 4 a szám: 9
# A helyet már kitöltötték.
#
# A kiválasztott sor: 3 oszlop: 6 a szám: 7
# A lépés megtehető.
#
# A kiválasztott sor: 6 oszlop: 6 a szám: 3
# Az adott résztáblázatban már szerepel a szám.
#
# A kiválasztott sor: 7 oszlop: 9 a szám: 8
# Az adott oszlopban már szerepel a szám.

# %% [markdown]
# # Utószó

# %% [markdown]
# Amennyiben a megoldás során használt kód megértése problémát okoz, látogasd meg a [Python alapjai kurzusomat](https://pythonvilag.hu/pv/python/alapok/), ahol részletesen bemutatom a Python programozási nyelv alapvető eszköztárát. <br> <br>
# További kidolgozott érettségi feladatokat pedig [az alábbi linken](https://pythonvilag.hu/pv/python/alapok/) éred el.
# <br> <br>
#
# Találkozunk a következő leckében!
