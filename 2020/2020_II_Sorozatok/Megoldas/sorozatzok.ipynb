# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Erettsegi_feladatok/blob/main/2020/2020_II_Sorozatok/Megoldas/sorozatzok.ipynb)

# %% [markdown]
# ## Feladat: [2020_II_Sorozatok](https://github.com/PythonVilag/Erettsegi_feladatok/blob/main/2020/2020_II_Sorozatok/Erettsegi/Sorozatok_FL.pdf) <br> <br>
#
#
# Készítette: Mizsák Dániel, Pecsenye Samu
#
# Minden jellegű visszajelzést örömmel fogadok az [alábbi e-mail címen.](mailto:info@pythonvilag.hu)

# %% [markdown]
# # Szükséges adatfájlok letöltése a futtató környezetbe

# %%
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2020/2020_II_Sorozatok/Forrasok/lista.txt
# Out:
# --2022-09-25 23:20:47--  https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2020/2020_II_Sorozatok/Forrasok/lista.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7329 (7.2K) [text/plain]
# Saving to: ‘lista.txt’
#
# lista.txt           100%[===================>]   7.16K  --.-KB/s    in 0s
#
# 2022-09-25 23:20:47 (83.4 MB/s) - ‘lista.txt’ saved [7329/7329]

# %% [markdown]
# # 1. Feladat

# %%
reszek = list()

with open(file='lista.txt', mode='r') as forras_file:
  for sorszam, sor in enumerate(forras_file):
    if sorszam % 5 == 0:
      resz = dict()
      resz['datum'] = sor.strip()
    elif sorszam % 5 == 1:
      resz['cim'] = sor.strip()
    elif sorszam % 5 == 2:
      resz['epizod'] = sor.strip()
    elif sorszam % 5 == 3:
      resz['hossz'] = sor.strip()
    elif sorszam % 5 == 4:
      resz['nezve'] = sor.strip()
      reszek.append(resz)

# %% [markdown]
# # 2. Feladat

# %%
print('\n2. feladat')

datumok_szama = 0
for resz in reszek:
  if resz['datum'] != 'NI':
    datumok_szama += 1
print(f'A listában {datumok_szama} db vetítési dátummal rendelkező epizód van.')

# %% [markdown]
# # 3. Feladat

# %%
print('\n3. feladat')

db_nezve = 0
for resz in reszek:
  if resz['nezve'] == '1':
    db_nezve += 1
nezve_arany = db_nezve/len(reszek)

print(f'A listában lévő epizódok {round(100*nezve_arany), 2}%-át látta.')

# %% [markdown]
# # 4. Feladat

# %%
print('\n4. feladat')

eltoltott_ido = 0
for resz in reszek:
  if resz['nezve'] == '1':
    eltoltott_ido += int(resz['hossz'])
percek = eltoltott_ido % 60
orak = (eltoltott_ido // 60) % 24
napok = eltoltott_ido // (60*24)
print('Sorozatnézéssel', end=' ')
if 0 < napok:
  print(f'{napok} napot', end=' ')
if 0 < napok or 0 < orak:
  print(f'{orak} orat', end=' ')
print(f'{percek} percet töltött')

# %% [markdown]
# # 5. Feladat

# %%
print('\n5. feldat')

bemeneti_datum_str = input('Adjon meg egy datumot! Datum=')
for resz in reszek:
  if resz['datum'] != 'NI':
    if resz['datum'] <= bemeneti_datum_str:  # string osszehasonlitas beturend szerint toretnik, ami it mukodik, mivel a vezeto nullakat is kiirjak a datumban
      if resz['nezve'] == '0':
        print(f'{resz["epizod"]}\t{resz["cim"]}')  # a belso idezojelek masok kell hogy legyenek mint a kulsők

# %% [markdown]
# # 6. Feladat

# %%
def hetnapja(ev:int, ho:int, nap:int) -> int:
  napok = "v h k sze cs p szo".split()
  honapok = (0, 3, 2, 5, 0, 3, 5, 1, 4, 6, 2, 4)
  if ho < 3: ev -= 1
  return napok[(ev+ev//4-ev//100+ev//400+honapok[ho-1] + nap) % 7]

# %% [markdown]
# # 7. Feladat

# %%
print('\n7. feladat')

bemeneti_nap = input('Adja meg a het egy napjat (pl.: cs) ! Nap=')
sorozatok = set()
for resz in reszek:
  if resz['datum'] != 'NI':
    ev_str, ho_str, nap_str = resz['datum'].split('.')
    ev_int = int(ev_str)
    ho_int = int(ho_str)
    nap_int = int(nap_str)
    if hetnapja(ev_int, ho_int, nap_int) == bemeneti_nap:
      sorozatok.add(resz['cim'])
for sorozat in sorozatok:
  print(sorozat)

# %% [markdown]
# # 8. Feladat

# %%
sorozatok = dict()
for resz in reszek:
  cim = resz['cim']
  hossz = resz['hossz']
  if cim not in sorozatok:
    sorozatok[cim] = {'hossz' : 0, 'darab' : 0}
        
  sorozatok[cim]['hossz'] += int(hossz)
  sorozatok[cim]['darab'] += 1

with open('summa.txt', 'w') as kimeneti_file:
  for cim in sorozatok:
    hossz = sorozatok[cim]['hossz']  # itt a cim egy str valtozo, a hossz pedig egy szoveg konstans
    darab = sorozatok[cim]['darab']
    print(f'{cim} {hossz} {darab}', file=kimeneti_file)

# %% [markdown]
# # Utószó

# %% [markdown]
# Amennyiben a megoldás során használt kód megértése problémát okoz, látogasd meg a [Python alapjai kurzusomat](https://pythonvilag.hu/pv/python/alapok/), ahol részletesen bemutatom a Python programozási nyelv alapvető eszköztárát. <br> <br>
# További kidolgozott érettségi feladatokat pedig [az alábbi linken](https://pythonvilag.hu/pv/python/alapok/) éred el.
# <br> <br>
#
# Találkozunk a következő leckében!
