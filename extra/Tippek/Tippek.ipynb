# %% [markdown]
# # Tippek és javaslatok emelt szintpő érettségi programozás feladatához

# %% [markdown]
# Általános tippek:
#
# - Mielőtt a feladat megoldásást elkezdenénk, olvassuk át a az egész feladatsort egyszer.
# - Az átolvasás alapján próbáljuk meg kitalálni, hogy érdemes-e bármi átalakítást végezni az adaton a beolvasás alatt (például értéket egész számmá alakítani), illetve milyen eredményeket kell elmentenünk későbbre.
# - Fontos, hogy a értékek elmentésére beszédes változóneveket használjunk és véletlenül azokat **ne írjuk felül**!

# %% [markdown]
# # Adatok beolvasása

# %% [markdown]
# Minden eddigi érettségi feladatban szükséges volt egy szöveges fájl tatalmát beolvasni és eltárolni.
#
# A beolvasás lépései:
# - Értsük meg, hogy hogyan áll össze az adat. Ez részletesen le van írva a feladat szövegében, de nyugondtan meg is tekinthetjük a fájl tartalmát manuálisan is. (Ügyelve, hogy abban nem írunk át semmit!)
# - Találjuk ki a beolvasott adat típusát. Ez sokszor egy lista, amiben listák vagy dictionary-k vannak, azokban pedig egész (int) vagy törtszámok (float), vagy szövegek (str).
# - Iteráljunk végig a beolvasott adaton és tültsük fel az elmentett változónkat.

# %% [markdown]
# ```python
# adatok = []
# ```
#
# - Hozzunk létre egy változót, amiben a beolvasott értékeket tároljuk majd el.

# %% [markdown]
# ```python
# with open("fajl_neve", mode="r") as forras_file:
# ```
#
# - Használjunk context managert (`with`), hogy biztosan ne felejtük el bezárni a fájlt.
# - Adjuk meg a beolvasás módját. Ez alapól `"r" = read` de így nem fogjuk elfelejteni megadni a `"w" = write`-nál sem.
# - Nevezzük ez a megnyitott fájlt az `as` kulcsszóval.

# %% [markdown]
# ```python
# for sorszam, sor in enumerate(forras_file):
# ```
#
# - Ha nem minden sorban ugyanolyan értékek vannak, használjuk az `enumerate` parancsot, így a sor számát is tudjuk vizsgálni az adatok elmentése során.
