# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Erettsegi_feladatok/blob/main/2021/2021_I_Godrok/Megoldas/godor.ipynb)

# %% [markdown]
# ## Feladat: [2021_I_Godrok](https://github.com/PythonVilag/Erettsegi_feladatok/blob/main/2021/2021_I_Godrok/Erettsegi/Godrok_FL.pdf) <br> <br>
#
#
# Készítette: Mizsák Dániel, Pecsenye Samu
#
# Minden jellegű visszajelzést örömmel fogadok az [alábbi e-mail címen.](mailto:info@pythonvilag.hu)

# %% [markdown]
# # Szükséges adatfájlok letöltése a futtató környezetbe

# %%
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2021/2021_I_Godrok/Forrasok/melyseg.txt
# Out:
# --2022-09-15 17:41:04--  https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2021/2021_I/Forrasok/melyseg.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1559 (1.5K) [text/plain]
# Saving to: ‘melyseg.txt’
#
# melyseg.txt         100%[===================>]   1.52K  --.-KB/s    in 0s
#
# 2022-09-15 17:41:04 (14.5 MB/s) - ‘melyseg.txt’ saved [1559/1559]

# %% [markdown]
# # 1. Feladat

# %%
print('1. feladat')

melysegek = list()
with open(file='melyseg.txt', mode='r') as forras_file:
  for sor in forras_file:
    elem = int(sor)
    melysegek.append(elem)

sorok_szama = len(melysegek)
print(f'A fájl adatainak száma: {sorok_szama}')
# Out:
# 1. feladat
# A fájl adatainak száma: 694

# %% [markdown]
# Alternatív megoldás (🐟):
#
# ```python
# ...
# with open(file='melyseg.txt', mode='r') as forras_file:
#     melysegek = list(map(int, forras_file))
# ...
#
# ```

# %% [markdown]
# # 2. Feladat

# %%
print('\n2. feladat')

bemeneti_sorszam = int(input('Adjon meg egy távolságértéket! ')) - 1
print(f'Ezen a helyen a felszín {melysegek[bemeneti_sorszam]} méter mélyen van.')
# Out:
# 2. feladat
# Adjon meg egy távolságértéket! 9
# Ezen a helyen a felszín 2 méter mélyen van.

# %% [markdown]
# # 3. Feladat

# %%
print('\n3. feladat')

nullak_szama = melysegek.count(0)
nullak_aranya = nullak_szama/len(melysegek)
print(f'Az érintetlen terület aránya {round(100 * nullak_aranya, 2)}%.')
# Out:
# 3. feladat
# Az érintetlen terület aránya 10.09%.

# %% [markdown]
# # 4. & 5. Feladat

# %%
print('\n5. feladat')

godrok_szama = 0
with open(file='godrok.txt', mode='w') as kimeneti_file:
  godor_list = list()
  for ertek in melysegek:
    if ertek == 0:
        if 0 < len(godor_list):
          print(' '.join(godor_list), file=kimeneti_file)
          godor_list = list()
          godrok_szama += 1
    else:
      godor_list.append(str(ertek))

print(f'A gödrök száma: {godrok_szama}')
# Out:
# 5. feladat
# A gödrök száma: 22

# %% [markdown]
# A `print(' '.join(godor_list), file=kimeneti_file)` sor az utolsó gödröt nem írná ki, ha a mélységek nem 0-val végződne, de a feladat szerint az első és utolsó érték mindig 0.

# %% [markdown]
# # 6. Feladat

# %%
print('\n6. feladat')

if melysegek[bemeneti_sorszam] == 0:
  print('Az adott helyen nincs gödör.')
else:
  print('a)')

  kezdet = bemeneti_sorszam
  while melysegek[kezdet] != 0:
    kezdet -= 1
  veg = bemeneti_sorszam
  while melysegek[veg] != 0:
    veg += 1

  # A kezdet és veg az első nullákra mutat, ezért eltoljuk eggyel
  kezdet += 1
  veg -= 1
  print(f'A gödör kezdete: {kezdet+1} méter, a gödör vége: {veg+1} méter.')
    
    
  print('b)')
  pozicio = kezdet

  while melysegek[pozicio] >= melysegek[pozicio - 1] and pozicio != veg:
    pozicio += 1
  while melysegek[pozicio] <= melysegek[pozicio - 1] and pozicio != veg:
    pozicio += 1
  if pozicio == veg:
      print('Folyamatosan mélyül.')
  else:
      print('Nem mélyül folyamatosan.')
    
    
  print('c)')
  print(f'A legnagyobb mélysége {max(melysegek[kezdet:veg+1])} méter.')

  print('d)')
  melyseg_osszeg = sum(melysegek[kezdet:veg+1])
  print(f'A térfogata {melyseg_osszeg*10} m^3.')
  
  print('e)')
  viz_osszeg = melyseg_osszeg - (veg-kezdet+1)
  print(f'A vízmennyiség {10*viz_osszeg} m^3.')
# Out:
# 6. feladat
# a)
# A gödör kezdete: 7 méter, a gödör vége: 22 méter.
# b)
# Nem mélyül folyamatosan.
# c)
# A legnagyobb mélysége 4 méter.
# d)
# A térfogata 440 m^3.
# e)
# A vízmennyiség 280 m^3.

# %% [markdown]
# # Utószó

# %% [markdown]
# Amennyiben a megoldás során használt kód megértése problémát okoz, látogasd meg a [Python alapjai kurzusomat](https://pythonvilag.hu/pv/python/alapok/), ahol részletesen bemutatom a Python programozási nyelv alapvető eszköztárát. <br> <br>
# További kidolgozott érettségi feladatokat pedig [az alábbi linken](https://pythonvilag.hu/pv/python/alapok/) éred el.
# <br> <br>
#
# Találkozunk a következő leckében!
