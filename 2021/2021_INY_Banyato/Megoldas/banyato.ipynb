# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Erettsegi_feladatok/blob/main/2021/2021_INY_Godrok/Megoldas/banyato.ipynb)

# %% [markdown]
# ## Feladat: [2021_INY_Banyato](https://github.com/PythonVilag/Erettsegi_feladatok/blob/main/2021/2021_INY_Banyato/Erettsegi/Banyato_FL.pdf) <br> <br>
#
#
# Készítette: Mizsák Dániel, Pecsenye Samu
#
# Minden jellegű visszajelzést örömmel fogadok az [alábbi e-mail címen.](mailto:info@pythonvilag.hu)

# %% [markdown]
# # Szükséges adatfájlok letöltése a futtató környezetbe

# %%
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2021/2021_INY_Banyato/Forrasok/melyseg.txt
# Out:
# --2022-09-19 10:27:12--  https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2021/2021_INY/Forrasok/melyseg.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2704 (2.6K) [text/plain]
# Saving to: ‘melyseg.txt’
#
# melyseg.txt         100%[===================>]   2.64K  --.-KB/s    in 0s
#
# 2022-09-19 10:27:12 (49.9 MB/s) - ‘melyseg.txt’ saved [2704/2704]

# %% [markdown]
# # 1. Feladat

# %%
# print('1. feladat')

with open('melyseg.txt', 'r') as forras_file:
  melyseg = list()
  for sorszam, sor in enumerate(forras_file):
    if sorszam == 0:
      sorok_szama = int(sor)
    elif sorszam == 1:
      oszlopok_szama = int(sor)
    else:
      sor_str_list = sor.strip().split()
      sor_int_list = list(map(int, sor_str_list))
      melyseg.append(sor_int_list)
# Out:
# 1. feladat
# Adja meg a bemeneti fájl nevét! konnyu.txt
# Adja meg egy sor számát! 1
# Adja meg egy oszlop számát! 1

# %% [markdown]
# # 2. Feladat

# %%
print('2. feladat')
bemeneti_sor = int(input('A meres soranak azonositoja=')) - 1
bemeneti_oszlop = int(input('A meres oszlopanak azonositoja=')) - 1

cella_melyseg = melyseg[bemeneti_sor][bemeneti_oszlop]
print(f'A mert melyseg az adott helyen {cella_melyseg} dm')

# %% [markdown]
# # 3. Feladat

# %%
print('\n3. feladat')

nem_felszin = 0
melyseg_osszeg = 0
for sor in melyseg:
  nem_felszin += sor.count(0)
  melyseg_osszeg += sum(sor)

meresek_szama = sorok_szama * oszlopok_szama
felszin = meresek_szama-nem_felszin
atlag_melyseg = melyseg_osszeg/felszin
print(f'A to felszine {felszin} m2, atlagos melysege: {atlag_melyseg/10:.2f} m')
# Out:
# 3. feladat
# Az adott helyen szereplő szám: 5
# A hely a(z) 1 résztáblázathoz tartozik.

# %% [markdown]
# A felulet a nem-nulla ertekek szama [m^2]-ben az atlag melyseg a melysegek osszege osztva a melysegek szamaval, átváltva m-be
#
# Alternativ:
# ```python
# nem_felszin = sum(map(lambda x: x.count(0), melyseg))
# melyseg_osszeg = sum(map(sum, melyseg))
# ```

# %% [markdown]
# # 4. Feladat

# %%
print('\n4. feladat')

max_ertek = -1
max_helyek = list()
for sorszam, sor_int_list in enumerate(melyseg):
  for oszlopszam, ertek in enumerate(sor_int_list):
      if max_ertek < ertek:
          max_ertek = ertek
          max_helyek = [(sorszam+1, oszlopszam+1),]  #+1 hogy kesobb ne kelljen meg1x vegigmenni rajtuk egyesevel a kiirashoz
      elif max_ertek == ertek:
          max_helyek.append((sorszam, oszlopszam))
print(f'A to legnagyobb melysege: {max_ertek} dm')
print('A legmelyebb helyek sor-oszlop koordinátái:')
# print(max_helyek)
# print(*max_helyek, sep='\t')
print('\t'.join(map(str, max_helyek)))  #hasonlit a peldara, de a sima print is jo
# Out:
# 4. feladat
# Az üres helyek aránya: 17.3%

# %% [markdown]
# # 5. Feladat

# %%
print('\n5. feladat')
partszakasz = 0
for sorszam in range(sorok_szama):
    for oszlopszam in range(oszlopok_szama):
        if 0 < oszlopszam:
            bal = melyseg[sorszam][oszlopszam-1]
            jobb = melyseg[sorszam][oszlopszam]
            if (bal == 0) != (jobb == 0):
                partszakasz += 1
        if 0 < sorszam:
            felso = melyseg[sorszam-1][oszlopszam]
            also = melyseg[sorszam][oszlopszam]
            if (felso == 0) != (also == 0):
                partszakasz += 1
# Out:
# 5. feladat
# A kiválasztott sor: 2 oszlop: 4 a szám: 9
# A helyet már kitöltötték.
#
# A kiválasztott sor: 3 oszlop: 6 a szám: 7
# A lépés megtehető.
#
# A kiválasztott sor: 6 oszlop: 6 a szám: 3
# Az adott résztáblázatban már szerepel a szám.
#
# A kiválasztott sor: 7 oszlop: 9 a szám: 8
# Az adott oszlopban már szerepel a szám.

# %% [markdown]
# # alternativ
# ```python
# partszakasz = 0
# for sor_int_list in melyseg:
#     for bal, jobb in zip(sor_int_list[:-1], sor_int_list[1:]):
#         if bool(bal) != bool(jobb):  # itt a != gyakorlatilag kizaro vagy (xor)
#             partszakasz += 1
# for oszlopszam in range(oszlopok_szama):
#     oszlop_int_list = [melyseg[k][oszlopszam] for k in range(sorok_szama)]
#     for felso, also in zip(oszlop_int_list[:-1], oszlop_int_list[1:]):
#         if bool(felso) != bool(also):
#             partszakasz += 1
# print(f'A to partvonala {partszakasz} m hosszu')
# ```

# %% [markdown]
# # 6. Feladat

# %%
print('\n6. feladat')
oszlop_azonosito_int = int(input('A vizsgalt szelveny oszlopanak azonositoja=')) - 1
with open('diagram.txt', 'w') as kimeneti_file:
    vizsgalt_oszlop = [melyseg[k][oszlop_azonosito_int] for k in range(sorok_szama)]
    for sorszam, ertek in enumerate(vizsgalt_oszlop):
        print(f'{sorszam:02d}{"*"*round(ertek/10)}', file=kimeneti_file)

# %% [markdown]
# ## alternativ
# ```python
# szam = f'{sorszam:02d}'
# csillagok = '*'*round(ertek/10)
# print(szam+csillagok, file=kimeneti_file)
# ```
# 02 a vezeto nullakat iratja ki 2 szamjegyig, d az intek betuje (floatoknal f)
# masfele idezojelet hasznalunk belul mint kivul, kulonben errort dob
# "string * int" muvelet int-szer egymas utan rakja a string-et
# print(file=) miatt a fileba ir a konzol helyett
# az alternativban a + pedig egymas utan fuz stringeket

# %% [markdown]
# # Utószó

# %% [markdown]
# Amennyiben a megoldás során használt kód megértése problémát okoz, látogasd meg a [Python alapjai kurzusomat](https://pythonvilag.hu/pv/python/alapok/), ahol részletesen bemutatom a Python programozási nyelv alapvető eszköztárát. <br> <br>
# További kidolgozott érettségi feladatokat pedig [az alábbi linken](https://pythonvilag.hu/pv/python/alapok/) éred el.
# <br> <br>
#
# Találkozunk a következő leckében!
