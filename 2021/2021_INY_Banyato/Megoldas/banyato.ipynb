# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Erettsegi_feladatok/blob/main/2021/2021_INY_Banyato/Megoldas/banyato.ipynb)

# %% [markdown]
# ## Feladat: [2021_INY_Banyato](https://github.com/PythonVilag/Erettsegi_feladatok/blob/main/2021/2021_INY_Banyato/Erettsegi/Banyato_FL.pdf) <br> <br>
#
#
# Készítette: Mizsák Dániel, Pecsenye Samu
#
# Minden jellegű visszajelzést örömmel fogadok az [alábbi e-mail címen.](mailto:info@pythonvilag.hu)

# %% [markdown]
# # Szükséges adatfájlok letöltése a futtató környezetbe

# %%
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2021/2021_INY_Banyato/Forrasok/melyseg.txt
# Out:
# --2022-09-25 18:20:17--  https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2021/2021_INY_Banyato/Forrasok/melyseg.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2704 (2.6K) [text/plain]
# Saving to: ‘melyseg.txt.1’
#
# melyseg.txt.1       100%[===================>]   2.64K  --.-KB/s    in 0s
#
# 2022-09-25 18:20:18 (53.8 MB/s) - ‘melyseg.txt.1’ saved [2704/2704]

# %% [markdown]
# # 1. Feladat

# %%
melysegek = list()

with open(file='melyseg.txt', mode='r') as forras_file:
  for sorszam, sor in enumerate(forras_file):
    if sorszam == 0:
      sorok_szama = int(sor)
    elif sorszam == 1:
      oszlopok_szama = int(sor)
    else:
      melyseg = sor.strip().split()
      melyseg = list(map(int, melyseg))
      melysegek.append(melyseg)

# %% [markdown]
# # 2. Feladat

# %%
print('2. feladat')

bemeneti_sor = int(input('A mérés sorának azonosítója=')) - 1
bemeneti_oszlop = int(input('A mérés oszlopának azonosítója=')) - 1

cella_melyseg = melysegek[bemeneti_sor][bemeneti_oszlop]
print(f'A mért mélység az adott helyen {cella_melyseg} dm')
# Out:
# 2. feladat
# A mérés sorának azonosítója=12
# A mérés oszlopának azonosítója=6
# A mért mélység az adott helyen 33 dm

# %% [markdown]
# # 3. Feladat

# %%
print('\n3. feladat')

nem_felszin = 0
melyseg_osszeg = 0
for sor in melysegek:
  nem_felszin += sor.count(0)
  melyseg_osszeg += sum(sor)

meresek_szama = sorok_szama * oszlopok_szama
felszin = meresek_szama - nem_felszin
atlag_melyseg = melyseg_osszeg / felszin
print(f'A tó felszíne: {felszin} m2, átlagos mélysége: {round(atlag_melyseg/10, 2)} m')
# Out:
# 3. feladat
# A tó felszíne: 646 m2, átlagos mélysége: 4.28 m

# %% [markdown]
# Alternatív megoldás (🐟):
# ```python
# nem_felszin = sum(map(lambda x: x.count(0), melysegek))
# melyseg_osszeg = sum(map(sum, melysegek))
# ...
# ```

# %% [markdown]
# # 4. Feladat

# %%
print('\n4. feladat')

max_ertek = -1
max_helyek = list()
for sorszam, sor in enumerate(melysegek):
  for oszlopszam, ertek in enumerate(sor):
    if max_ertek < ertek:
      max_ertek = ertek
      max_helyek = [(sorszam + 1, oszlopszam + 1)]
    elif max_ertek == ertek:
        max_helyek.append((sorszam + 1, oszlopszam + 1))

print(f'A tó legnagyobb mélysége: {max_ertek} dm')
print('A legmélyebb helyek sor-oszlop koordinátái:')
for max_hely in max_helyek:
  print(f'({max_hely[0]}; {max_hely[1]})', end='\t')
# Out:
# 4. feladat
# A tó legnagyobb mélysége: 98 dm
# A legmélyebb helyek sor-oszlop koordinátái:
# (14; 20)	(26; 11)	(32; 16)

# %% [markdown]
# # 5. Feladat

# %%
print('\n5. feladat')

partszakasz = 0

for sorszam in range(sorok_szama):
  for oszlopszam in range(oszlopok_szama):
    if oszlopszam > 0:
      bal = melysegek[sorszam][oszlopszam-1]
      jobb = melysegek[sorszam][oszlopszam]
      if (bal == 0) != (jobb == 0):
        partszakasz += 1
    if sorszam > 0:
      felso = melysegek[sorszam-1][oszlopszam]
      also = melysegek[sorszam][oszlopszam]
      if (felso == 0) != (also == 0):
        partszakasz += 1

print(f'A tó partvonala {partszakasz} m hosszú')
# Out:
# 5. feladat
# A tó partvonala 270 m hosszú

# %% [markdown]
# # 6. Feladat

# %%
print('\n6. feladat')

oszlop_azonosito = int(input('A vizsgált szelvény oszlopának azonosítója=')) - 1
vizsgalt_oszlop = [melysegek[k][oszlop_azonosito] for k in range(sorok_szama)]

with open(file='diagram.txt', mode='w') as kimeneti_file:
  for sorszam, ertek in enumerate(vizsgalt_oszlop):
    sorszam = f'{sorszam+1:02d}'
    csillagok = round(ertek/10)*'*'
    print(f'{sorszam}{csillagok}', file=kimeneti_file)
# Out:
# 6. feladat
# A vizsgált szelvény oszlopának azonosítója=6

# %% [markdown]
# # Utószó

# %% [markdown]
# Amennyiben a megoldás során használt kód megértése problémát okoz, látogasd meg a [Python alapjai kurzusomat](https://pythonvilag.hu/pv/python/alapok/), ahol részletesen bemutatom a Python programozási nyelv alapvető eszköztárát. <br> <br>
# További kidolgozott érettségi feladatokat pedig [az alábbi linken](https://pythonvilag.hu/pv/python/alapok/) éred el.
# <br> <br>
#
# Találkozunk a következő leckében!
