# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Erettsegi_feladatok/blob/main/2023/2023_U_Konyha/Megoldas/etel.ipynb)

# %% [markdown]
# ## Feladat: [2023_U_Konyha](https://github.com/PythonVilag/Erettsegi_feladatok/blob/main/2023/2023_U_Konyha/Erettsegi/Etelek_FL.txt) <br> <br>
#
#
# Készítette: Mizsák Dániel, Pecsenye Samu
#
# Minden jellegű visszajelzést örömmel fogadok az [alábbi e-mail címen.](mailto:info@pythonvilag.hu)

# %% [markdown]
# # Szükséges adatfájlok letöltése a futtató környezetbe

# %%
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2023/2023_U_Konyha/Forrasok/etelek.txt
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2023/2023_U_Konyha/Forrasok/kremes.txt
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2023/2023_U_Konyha/Forrasok/krumplileves.txt
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2023/2023_U_Konyha/Forrasok/krumplisteszta.txt
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2023/2023_U_Konyha/Forrasok/makaroni.txt
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2023/2023_U_Konyha/Forrasok/muffin.txt
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2023/2023_U_Konyha/Forrasok/palacsinta.txt
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2023/2023_U_Konyha/Forrasok/paradicsomleves.txt
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2023/2023_U_Konyha/Forrasok/rantotthus.txt
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2023/2023_U_Konyha/Forrasok/tojasleves.txt

# %% [markdown]
# # 1. Feladat

# %%
fogasok = {"leves": [], "foetel": [], "desszert": []}

with open(file='etelek.txt', mode='r', encoding='utf-8') as forras_file:
  for sor in forras_file:
    sor = sor.strip()
    etel = sor.split(" ")[1]
    if "leves" in sor:
      fogasok["leves"].append(etel)
    elif "foetel" in sor:
      fogasok["foetel"].append(etel)
    elif "desszert" in sor:
      fogasok["desszert"].append(etel)

etelek = {}
for fogas in fogasok:
  for etel in fogas[fogas]:
    with open(file=f"{etel}.txt", mode="r", encoding="utf-8") as forras_file:
      etelek[etel] = forras_file.read()


for kategoria in etelek:
  print(f"{kategoria} ({len(etelek[kategoria])}):")
  print(" - ".join(sorted(etelek[kategoria])))
  print()
# Out:
# Leves:
# paradicsomleves - tojasleves - krumplileves
#
# Foetel:
# krumplisteszta - makaroni - rantotthus
#
# Desszert:
# palacsinta - muffin - kremes

# %% [markdown]
# # 2. Feladat

# %%
print("2. feladat.")

lisztes_etelek = []

for etel in etelek:
  if "liszt" in etelek[etel]:
    lisztes_etelk.append(etel)
# Out:
# 2. feladat.
# Összesen 9 étel szerepel az adatok között.

# %% [markdown]
# # 3. Feladat

# %%
print('3. feladat')

legkevesbe_szeretett_etel = input(f"Az alábbi ételek közül melyiket szereti legkevésbé: {' '.join(lisztes_etelek)}?")

import random
megmaradt_lisztes_etelek = lisztes_etelek.remove(legkevesbe_szeretett_etel)
veletlenszeruen_valasztott_etel = random.choice(megmaradt_lisztes_etelek)

print(f"Véletlenszerűen választott étel: {veletlenszeruen_valasztott_etel}")
# Out:
# 3. feladat
# A véletlenszerűen kiválasztott kategória: Leves és azt étel: tojasleves

# %% [markdown]
# # 4. Feladat

# %%
bekert_foetel = input("Kiválasztott főétel: ")

mertekegysegek = []
for etel in etelek:
  for sor in etelek[etel]:
    sor = sor.strip()
    mertekegyseg = sor.split(" ")[1]
    if mertekegyseg not in mertekegysegek:
      mertekegysegek.append(mertekegyseg)

print(f"A(z) {bekert_foetel} receptjében található mértékegységek: {mertekegysegek}")

# %% [markdown]
# # 5. Feladat

# %% [markdown]
# # Utószó

# %% [markdown]
# Amennyiben a megoldás során használt kód megértése problémát okoz, látogasd meg a [Python alapjai kurzusomat](https://pythonvilag.hu/pv/python/alapok/), ahol részletesen bemutatom a Python programozási nyelv alapvető eszköztárát. <br> <br>
# További kidolgozott érettségi feladatokat pedig [az alábbi linken](https://pythonvilag.hu/pv/python/alapok/) éred el.
# <br> <br>
#
# Találkozunk a következő leckében!
