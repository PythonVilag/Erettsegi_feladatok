# %% [markdown]
# `A kód futtatható verziójának a megnyitása:`
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/PythonVilag/Erettsegi_feladatok/blob/main/2023/2023_I_RENAMEME/Megoldas/RENAMEME.ipynb)

# %% [markdown]
# ## Feladat: [2023_I_RENAMEME](https://github.com/PythonVilag/Erettsegi_feladatok/blob/main/2023/2023_I_RENAMEME/Erettsegi/RENAMEME_FL.pdf) <br> <br>
#
#
# Készítette: Mizsák Dániel, Pecsenye Samu
#
# Minden jellegű visszajelzést örömmel fogadok az [alábbi e-mail címen.](mailto:info@pythonvilag.hu)

# %% [markdown]
# # Szükséges adatfájlok letöltése a futtató környezetbe

# %%
# !wget https://raw.githubusercontent.com/PythonVilag/Erettsegi_feladatok/main/2023/2023_I_RENAMEME/Forrasok/RENAMEME.txt

# %% [markdown]
# # 1. Feladat

# %% [markdown]
# # 2. Feladat

# %% [markdown]
# # 3. Feladat

# %% [markdown]
# # 4. Feladat

# %% [markdown]
# # 5. Feladat

# %% [markdown]
# # 6. Feladat

# %% [markdown]
# #7. Feladat

# %% [markdown]
# # Utószó

# %% [markdown]
# Amennyiben a megoldás során használt kód megértése problémát okoz, látogasd meg a [Python alapjai kurzusomat](https://pythonvilag.hu/pv/python/alapok/), ahol részletesen bemutatom a Python programozási nyelv alapvető eszköztárát. <br> <br>
# További kidolgozott érettségi feladatokat pedig [az alábbi linken](https://pythonvilag.hu/pv/python/alapok/) éred el.
# <br> <br>
#
# Találkozunk a következő leckében!
